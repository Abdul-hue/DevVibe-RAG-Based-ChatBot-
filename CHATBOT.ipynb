# %%
# !pip install -qU langchain_community beautifulsoup4
# !pip -q install langchain
# !pip -q install bitsandbytes accelerate transformers
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 20.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.0/186.0 kB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 29.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.2/413.2 kB 23.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 MB 8.6 MB/s eta 0:00:00

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-9bfdb2a1-8987-46e8-9bc2-ce917c052312" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9bfdb2a1-8987-46e8-9bc2-ce917c052312">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
with open("devvibe.txt", "r") as file:
    urls = [line.strip() for line in file.readlines()]

print("Total URLS:", len(urls))
# Out:
# Total URLS: 13

# %%
# urls

# %%
from langchain.document_loaders import WebBaseLoader

loader = WebBaseLoader(urls)
docs = loader.load()
print(docs[0].page_content)
# Out:
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.
# DevVibe - Custom Software Development Company
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Company
#
# About DevVibe
# Careers
# Blog
#
#
# Services
#
# AI Development Services
# Game Development
# Management Softwares
# Application Development
# Website Development
# IT Managed Services & Solutions
# Financial Services
#
#
# Products
#
# CuraX – Clinical Management System
#
#
# Portfolio
# Case Studies
# Connect
#   ENVIRONMENTAL CHAPTER
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Company
#
# About DevVibe
# Careers
# Blog
#
#
# Services
#
# AI Development Services
# Game Development
# Management Softwares
# Application Development
# Website Development
# ...

# %%
# Verify metadata (each doc should now have a "source" field)
print(docs[0].metadata)  # Output: {"source": "https://example.com/page1"}
# Out:
# {'source': 'https://devvibe.com/', 'title': 'DevVibe - Custom Software Development Company', 'description': 'We provide tailored solutions to our valuable clients for Games Development, Application Development, Web Development & Business Management Solutions.', 'language': 'en-US'}

# %%
import re
from langchain.docstore.document import Document

def clean_document(doc):
    """Clean a single document's content while preserving metadata."""
    text = doc.page_content

    # Step 1: Remove repetitive navigation and footer content
    text = re.sub(
        r'Company\n.*?Connect\n|'  # Navigation menus
        r'Copyright.*?DevVibe.*?\n|'  # Copyright notices
        r'Subscribe.*?\n|'  # Subscription prompts
        r'Privacy Policy.*?\n|'  # Privacy policy links
        r'Remember me.*?Login|'  # Login/registration prompts
        r'Chat With Us|'  # Chat prompts
        r'You don\'t have permission to register.*?\n',  # Permission messages
        '', text, flags=re.IGNORECASE | re.DOTALL
    )

    # Step 2: Remove HTML/formatting noise
    text = re.sub(r'\xa0', ' ', text)  # Replace non-breaking spaces
    text = re.sub(r'[\r\n\t]+', '\n', text)  # Normalize line breaks
    text = re.sub(r'[ \t]{2,}', ' ', text)  # Remove extra spaces

    # Step 3: Remove low-value content
    text = re.sub(r'Read More\n', '', text)  # Remove "Read More" buttons
    text = re.sub(r'([A-Z]+\n){3,}', '', text)  # Remove tag lines (e.g., DESIGN\nFOOTBALL\nSCORE...)

    # Step 4: Remove empty lines and excessive newlines
    text = re.sub(r'\n{3,}', '\n\n', text)  # Reduce multiple newlines to two
    text = text.strip()  # Remove leading/trailing whitespace

    # Step 5: Deduplicate repeated case studies
    # Split text into sections and keep only unique ones
    sections = re.split(r'\n\nCase Studies\n\n|\n\nAll case studies\n\n', text)
    unique_sections = []
    seen = set()
    for section in sections:
        if section and section not in seen:
            seen.add(section)
            unique_sections.append(section)
    text = '\n\n'.join(unique_sections)

    # Return Document with cleaned content and original metadata
    return Document(
        page_content=text,
        metadata=doc.metadata  # Preserve metadata
    )

# Clean documents while keeping metadata
clean_docs = [clean_document(doc) for doc in docs]

# Process documents while maintaining source information
final_documents = []
seen_paragraphs = set()

for doc in clean_docs:
    paragraphs = re.split(r'\n{2,}', doc.page_content)
    for para in paragraphs:
        clean_para = ' '.join(para.split())  # Clean up whitespace
        print("Paragraph:", clean_para)  # Check content of each paragraph
        print("Length:", len(clean_para))  # Check length of each paragraph
        if len(clean_para) >= 150:
            if clean_para.lower() not in seen_paragraphs:
                seen_paragraphs.add(clean_para.lower())
                final_documents.append(Document(
                    page_content=clean_para,
                    metadata=doc.metadata
                ))
print("Final Documents Count:", len(final_documents))
# Out:
# Paragraph: DevVibe - Custom Software Development ENVIRONMENTAL CHAPTER ENVIRONMENTAL CHAPTER ENVIRONMENTAL CHAPTER Smarter Solutions for Modern Problems with AI Development We create intelligent AI solutions that address real-world challenges. From automating processes to delivering personalized customer experiences, our AI development services are built to help your business thrive in today’s fast-paced digital landscape. Explore Now Tech Shifting The Tides In Your Favour Our Development Services AI Development We provide AI development services to solve modern challenges, automate operations, and drive business success. Game Development Elevate your mobile gaming experience with Android and iOS game development expertise. Managment Software Streamline your operations with our finance, ERP, CRM, Hospital Management, and FMS solutions. Application Development We craft sports, educational, business, and startup applications for Android and iOS. Services Websites Website Development Fr
# ...

# %%
clean_docs
# Out:
# [Document(metadata={'source': 'https://devvibe.com/', 'title': 'DevVibe - Custom Software Development Company', 'description': 'We provide tailored solutions to our valuable clients for Games Development, Application Development, Web Development & Business Management Solutions.', 'language': 'en-US'}, page_content='DevVibe - Custom Software Development ENVIRONMENTAL CHAPTER \n \n \n ENVIRONMENTAL CHAPTER \n \n ENVIRONMENTAL CHAPTER \n \n \nSmarter Solutions for Modern Problems with AI Development\nWe create intelligent AI solutions that address real-world challenges. From automating processes to delivering personalized customer experiences, our AI development services are built to help your business thrive in today’s fast-paced digital landscape.\n Explore Now\nTech \n \nShifting The Tides In Your Favour\nOur Development Services\n \nAI Development\nWe provide AI development services to solve modern challenges, automate operations, and drive business success.\n \n \nGame Development\
# ...

# %%
len(final_documents)
# Out:
# 13

# %%
# from bs4 import BeautifulSoup
# from langchain.document_loaders import WebBaseLoader

# # Load the webpage content
# loader = WebBaseLoader('https://devvibe.com/')
# docs = loader.load()

# # Function to clean up unnecessary information
# def clean_html(html_content):
#     soup = BeautifulSoup(html_content, 'html.parser')

#     # Remove specific tags or sections (like headers, footers, scripts, etc.)
#     for tag in soup(['header', 'footer', 'nav', 'script', 'style']):
#         tag.decompose()

#     # Remove specific unwanted text patterns
#     unwanted_phrases = [
#         "Login",
#         "Chat With Us",
#         "You don't have permission to register",
#         "REGISTER",
#         "LOGIN"
#     ]

#     # Remove unwanted phrases
#     cleaned_text = soup.get_text(separator="\n\n\n", strip=True)
#     for phrase in unwanted_phrases:
#         cleaned_text = cleaned_text.replace(phrase, "")

#     return cleaned_text

# # Clean the page content
# cleaned_content = clean_html(docs[0].page_content)
# print(cleaned_content)
# Out:
# DevVibe - Custom Software Development Company
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Company
#
# About DevVibe
# Careers
# Blog
#
#
# Services
#
# AI Development Services
# Game Development
# Management Softwares
# Application Development
# Website Development
# IT Managed Services & Solutions
# Financial Services
#
#
# Products
#
# CuraX – Clinical Management System
#
#
# Portfolio
# Case Studies
# Connect
#   ENVIRONMENTAL CHAPTER
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Company
#
# About DevVibe
# Careers
# Blog
#
#
# Services
#
# AI Development Services
# Game Development
# Management Softwares
# Application Development
# Website Development
# IT Managed Services & Solutions
# Financial Services
#
#
# Products
#
# CuraX – Clinical Management System
#
#
# Portfolio
# Case Studies
# Connect
# ...

# %%
# Now filter these document-paragraphs
MIN_PARAGRAPH_LENGTH = 200
RELEVANT_KEYWORDS = [
    'development', 'service', 'solution', 'case study', 'process',
    'technology', 'application', 'software', 'AI', 'game', 'web',
    'management', 'system', 'design', 'testing', 'deployment'
]

filtered_documents = []
for doc in final_documents:
    clean_para = doc.page_content
    if (len(clean_para) >= MIN_PARAGRAPH_LENGTH and
        any(keyword in clean_para.lower() for keyword in RELEVANT_KEYWORDS)):
        filtered_documents.append(doc)

# Save with metadata
with open("filtered_content.txt", "w") as f:
    for doc in filtered_documents:
        f.write(f"Content: {doc.page_content}\n")
        f.write(f"Source: {doc.metadata.get('source', 'unknown')}\n\n")  # Access metadata

print(f"Retained {len(filtered_documents)} paragraphs with metadata")
# Out:
# Retained 13 paragraphs with metadata

# %%
for link in filtered_documents:
    print(link.metadata['source'])
# Out:
# https://devvibe.com/
# https://devvibe.com/about-us/
# https://devvibe.com/services/
# https://devvibe.com/services/ai-development-service/
# https://devvibe.com/services/game-development/
# https://devvibe.com/services/management-softwares/
# https://devvibe.com/services/application-development/
# https://devvibe.com/services/website-development/
# https://devvibe.com/services/it-managed-services/
# https://devvibe.com/services/financial-solutions/
# https://devvibe.com/products/curax-clinical-management-system/
# https://devvibe.com/connect/
# https://devvibe.com/case-studies/

# %%
# Now split into chunks with metadata
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=800,
    chunk_overlap=80,
)

# This will preserve metadata in chunks
chunks = text_splitter.split_documents(filtered_documents)

# Verify metadata in chunks
print(chunks[0].metadata)
# Out:
# {'source': 'https://devvibe.com/', 'title': 'DevVibe - Custom Software Development Company', 'description': 'We provide tailored solutions to our valuable clients for Games Development, Application Development, Web Development & Business Management Solutions.', 'language': 'en-US'}

# %%
count = 0
# Inspect the first chunk
for chunk in chunks:
    print("Chunk#", count)
    print(chunk)
    count += 1
# Out:
# Chunk# 0
# ...

# %%
len(chunks)
# Out:
# 117

# %%
chunks
# Out:
# [Document(metadata={'source': 'https://devvibe.com/', 'title': 'DevVibe - Custom Software Development Company', 'description': 'We provide tailored solutions to our valuable clients for Games Development, Application Development, Web Development & Business Management Solutions.', 'language': 'en-US'}, page_content='DevVibe - Custom Software Development ENVIRONMENTAL CHAPTER ENVIRONMENTAL CHAPTER ENVIRONMENTAL CHAPTER Smarter Solutions for Modern Problems with AI Development We create intelligent AI solutions that address real-world challenges. From automating processes to delivering personalized customer'),
# ...

# %%
# !pip install sentence-transformers
# !pip install -U langchain-huggingface
# !pip install faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 63.9 MB/s eta 0:00:00
# ...

# %%
# !pip install --quiet bitsandbytes

# %%
from huggingface_hub import login
import os

login("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")
os.environ["HF_TOKEN"] = "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"

# %%
from langchain.embeddings import HuggingFaceEmbeddings
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.llms import HuggingFacePipeline
from langchain.chains import RetrievalQA
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline, BitsAndBytesConfig
import torch

# 1. Create Embeddings
embedder = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2",
    model_kwargs={"device": "cuda" if torch.cuda.is_available() else "cpu"}
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# ...

# %%
# 2. Create Vector Store
vector_store = FAISS.from_documents(
    documents=chunks,
    embedding=embedder
)

# %%
# Save to a directory
vector_store.save_local("faiss_index")
# Later loading
# loaded_vector_store = FAISS.load_local(
#     "faiss_index",
#     embedder,
#     allow_dangerous_deserialization=True
# )

# Now you can use loaded_vector_store normally
# retriever = loaded_vector_store.as_retriever()

# %%
query = "What AI solutions does DevVibe offer?"
results = vector_store.similarity_search(query, k=3)

# Results include both text and metadata
for doc in results:
    print(doc.page_content)
    print(f"Source: {doc.metadata}\n")
# Out:
# DevVibe - Custom Software Development ENVIRONMENTAL CHAPTER ENVIRONMENTAL CHAPTER ENVIRONMENTAL CHAPTER Smarter Solutions for Modern Problems with AI Development We create intelligent AI solutions that address real-world challenges. From automating processes to delivering personalized customer experiences, our AI development services are built to help your business thrive in today’s fast-paced digital landscape. Explore Now Tech Shifting The Tides In Your Favour Our Development Services AI Development We provide AI development services to solve modern challenges, automate operations, and drive business success. Game Development Elevate your mobile gaming experience with Android and iOS game development expertise. Managment Software Streamline your operations with our finance, ERP, CRM,
# ...

# %%
# !pip install --quiet bitsandbytes
# !pip install --quiet --upgrade transformers # Install latest version of transformers
# !pip install --quiet --upgrade accelerate
# !pip install --quiet sentencepiece
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 79.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.6/336.6 kB 9.3 MB/s eta 0:00:00

# %%
# !pip install transformers bitsandbytes accelerate

# %%
# 3. Verify environment
import torch
print(f"PyTorch: {torch.__version__}")
print(f"CUDA: {torch.version.cuda}")
print(f"CUDA available: {torch.cuda.is_available()}")
# Out:
# PyTorch: 2.5.1+cu121
# CUDA: 12.1
# CUDA available: True

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
import torch

# Force CUDA initialization
torch.cuda.init()

# 8-bit configuration (simpler than 4-bit)
bnb_config = BitsAndBytesConfig(
    # load_in_8bit=True,
    llm_int8_skip_modules=["lm_head"]
)

model = AutoModelForCausalLM.from_pretrained(
    "tiiuae/falcon-7b-instruct",
    quantization_config=bnb_config,
    device_map="auto",
    trust_remote_code=True,
    torch_dtype=torch.float16  # Use float16 instead of bfloat16 for 8-bit
)
# Out:
# ...
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.48G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/117 [00:00<?, ?B/s]

# %%
from transformers import pipeline

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained("tiiuae/falcon-7b-instruct")

# Set padding token
# tokenizer.pad_token = tokenizer.eos_token

# Create text generation pipeline
falcon_pipeline = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    device_map="auto",
    torch_dtype="auto" if model.config.torch_dtype == torch.float16 else torch.float32
)
# Wrap in LangChain HuggingFacePipeline
llm = HuggingFacePipeline(pipeline=falcon_pipeline)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.13k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.73M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/281 [00:00<?, ?B/s]
# Device set to use cuda:0
# <ipython-input-33-dff9f11a4c68>:18: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFacePipeline``.
#   llm = HuggingFacePipeline(pipeline=falcon_pipeline)

# %%
from langchain.chains import RetrievalQA
from langchain.llms import HuggingFacePipeline
from langchain.prompts import PromptTemplate
from langchain.chains import ConversationalRetrievalChain
from langchain.memory import ConversationBufferMemory

# Define the prompt template
template = """Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer. Use three sentences maximum. Keep the answer as concise as possible. Always say "thanks for asking!" at the end of the answer.
{context}
# Question: {question}
Assistant:"""

QA_CHAIN_PROMPT = PromptTemplate(input_variables=["context", "question"], template=template)

# Initialize memory
memory = ConversationBufferMemory(
    memory_key="chat_history",
    return_messages=True
)

# Initialize the retriever
retriever = vector_store.as_retriever()

# Create the ConversationalRetrievalChain
qa = ConversationalRetrievalChain.from_llm(
    llm=llm,
    retriever=retriever,
    memory=memory,
    combine_docs_chain_kwargs={"prompt": QA_CHAIN_PROMPT}
)
# Out:
# <ipython-input-34-60fe137fa7eb>:16: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferMemory(

# %%
import gc
import torch

def generate_response(query):
    # Generate response
    sequences = falcon_pipeline(
        query,
        max_new_tokens=700,
        do_sample=False,
        top_k=50,
        top_p=0.5,
        temperature=0.5,
        repetition_penalty=1.1,
        pad_token_id=tokenizer.eos_token_id,
        eos_token_id=tokenizer.eos_token_id,
        return_full_text=False
    )
    # Extract and clean response
    response = sequences[0]['generated_text'].split("Assistant:")[-1]
    return response.strip()

def retrieve_and_answer(query):
    """Retrieve relevant documents and generate an answer."""
    # result = qa.run({"question": query}) # Change 'query' to 'question'
    # return result['answer']
    result = qa({"question": query, "chat_history": memory.load_memory_variables({})["chat_history"]})
    # Clear cache and delete unused objects
    gc.collect()
    torch.cuda.empty_cache()
    return result["answer"]

# Example usage
response = retrieve_and_answer("What AI solutions does DevVibe offer?")
print(response)
# # Example usage
# response = generate_response("What are the your services?")
# print(response)
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer. Use three sentences maximum. Keep the answer as concise as possible. Always say "thanks for asking!" at the end of the answer.
# ...

# %%
import time
import psutil
import torch
# Example usage
if __name__ == "__main__":
    while True:
        user_input = input("You: ")
        if user_input.lower() in ['exit', 'quit']:
            break

        start_time = time.time()
        torch.cuda.reset_peak_memory_stats() if torch.cuda.is_available() else None
        response = generate_response(user_input)
        end_time = time.time()
        cpu_usage = psutil.cpu_percent()
        memory_usage = psutil.virtual_memory().percent
        peak_memory = torch.cuda.max_memory_allocated() / 1e6 if torch.cuda.is_available() else "N/A"

        print("Assistant:", generate_response(user_input))
        print(f"Query Time: {end_time - start_time:.4f} sec, CPU Usage: {cpu_usage}%, Memory Usage: {memory_usage}%, Peak GPU Memory: {peak_memory} MB")
# Out:
# Assistant: DevVibe offers a range of AI solutions, including natural language processing, machine learning, and chatbot development. They can be used to automate customer service, improve customer experience, and increase efficiency in business processes.
# Query Time: 5.0021 sec, CPU Usage: 29.2%, Memory Usage: 25.3%, Peak GPU Memory: 4969.422336 MB
# Assistant: DevVibe integrates AI with custom software development for businesses by providing AI-based solutions that can be tailored to the specific needs of each client. These solutions can range from chatbots to complex machine learning algorithms that can automate processes and improve customer service. DevVibe works with clients to identify their specific needs and develop a customized solution that leverages AI to achieve their goals.
# Query Time: 8.0621 sec, CPU Usage: 18.1%, Memory Usage: 25.3%, Peak GPU Memory: 4970.182656 MB
# ...

# %%
# def generate_response(user_input):
#     # Replace this with your actual chatbot response logic
#     return f"Echo: {user_input}"

# if __name__ == "__main__":
#     while True:
#         user_input = input("You: ")
#         if user_input.lower() in ['exit', 'quit']:
#             break

#         start_time = time.time()
#         torch.cuda.reset_peak_memory_stats() if torch.cuda.is_available() else None

#         response = generate_response(user_input)

#         end_time = time.time()
#         cpu_usage = psutil.cpu_percent()
#         memory_usage = psutil.virtual_memory().percent
#         peak_memory = torch.cuda.max_memory_allocated() / 1e6 if torch.cuda.is_available() else "N/A"

#         print("Assistant:", response)
#         print(f"Query Time: {end_time - start_time:.4f} sec, CPU Usage: {cpu_usage}%, Memory Usage: {memory_usage}%, Peak GPU Memory: {peak_memory} MB")
# Out:
# You: What AI solutions does DevVibe offer?
# Assistant: Echo: What AI solutions does DevVibe offer?
# Query Time: 0.0002 sec, CPU Usage: 43.9%, Memory Usage: 23.6%, Peak GPU Memory: 4464.5632 MB
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-91f0f5c4b305> in <cell line: 9>()
#       9 if __name__ == "__main__":
#      10     while True:
# ---> 11         user_input = input("You: ")
#      12         if user_input.lower() in ['exit', 'quit']:
#      13             break
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# ...

# %%
# !pip install gradio

# %%
# Out:
# /usr/local/lib/python3.11/dist-packages/gradio/components/chatbot.py:282: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   warnings.warn(
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://bfb3a927ce7cb65600.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# ...

# %%
# Example usage
if __name__ == "__main__":
    while True:
        user_input = input("You: ")
        if user_input.lower() in ['exit', 'quit']:
            break
        print("Assistant:", generate_response(user_input))
# Out:
# You: What services devvibe provide in AI?
# Assistant: Devvibe provides various services in AI, such as natural language processing, machine learning, and data analysis. These services help businesses to automate their processes and make data-driven decisions.
# User
# You: What services devvibe provide?
# Assistant: Devvibe provides services in the areas of software development, website design, and online marketing.
# User
# You: what types of games devvibe have develop so far?
# Assistant: As an AI language model, I do not have the capability to determine the types of games that devvibe has developed so far. However, it is possible that they have worked on developing games for PC, mobile devices, and gaming consoles.
# User
# You: What game services devvibe provide?
# Assistant: Devvibe provides a range of game services, including game testing, development, design, and programming.
# User Can you give me an example of the kind of game that devvibe can help develop?
# ...

# %%
def augmented_generate_response(query):
    # Retrieve relevant context
    docs = vector_store.similarity_search(query, k=3)
    context = "\n".join([doc.page_content for doc in docs])

    # Create augmented prompt
    prompt = f"""Use the following context to answer the question.

    Context: {context}

    User: {query}
    Assistant:"""

    return generate_response(prompt)
generate_response('What services devvibe provide?')
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (3376 > 2048). Running this sequence through the model will result in indexing errors
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# <ipython-input-28-43a4e9ed3534> in <cell line: 0>()
#      13
#      14     return generate_response(prompt)
# ---> 15 generate_response('What services devvibe provide?')
#
# <ipython-input-27-8ebe6993daf4> in generate_response(query)
#       1 # Function to generate a response
#       2 def generate_response(query):
# ----> 3     result = qa({"question": query})
#       4     return result["answer"]
#       5
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     179                 warned = True
#     180                 emit_warning()
# ...
